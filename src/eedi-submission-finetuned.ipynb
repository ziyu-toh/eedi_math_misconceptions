# %%
# !pip install --no-index --find-links /kaggle/input/eedi-library-lln pip3_autoremove
# !pip-autoremove torch torchvision torchaudio -y
# !pip install --no-index --find-links /kaggle/input/eedi-library-lln torch torchvision torchaudio
# !pip install --no-index --find-links /kaggle/input/eedi-library-lln xformers unsloth sentence_transformers
# Out:
# Looking in links: /kaggle/input/eedi-library-lln
# Processing /kaggle/input/eedi-library-lln/pip3_autoremove-1.2.2-py2.py3-none-any.whl
# Requirement already satisfied: pip in /opt/conda/lib/python3.10/site-packages (from pip3_autoremove) (24.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from pip3_autoremove) (70.0.0)
# Installing collected packages: pip3_autoremove
# Successfully installed pip3_autoremove-1.2.2
# dill 0.3.8 is installed but dill<0.3.2,>=0.3.1.1 is required
# Redoing requirement with just package name...
# cloudpickle 3.1.0 is installed but cloudpickle~=2.2.1 is required
# Redoing requirement with just package name...
# numpy 1.26.4 is installed but numpy<1.25.0,>=1.14.3 is required
# Redoing requirement with just package name...
# pyarrow 17.0.0 is installed but pyarrow<10.0.0,>=3.0.0 is required
# Redoing requirement with just package name...
# jupyterlab 4.3.1 is installed but jupyterlab~=3.6.0 is required
# Redoing requirement with just package name...
# google-cloud-bigquery 2.34.4 is installed but google-cloud-bigquery[bqstorage,pandas]>=3.10.0 is required
# Redoing requirement with just package name...
# google-cloud-storage 1.44.0 is installed but google-cloud-storage>=2.0.0 is required
# Redoing requirement with just package name...
# pandas 2.2.3 is installed but pandas<2.1.4,>=1.5.0 is required
# Redoing requirement with just package name...
# numpy 1.26.4 is installed but numpy<3.0.0,>=2.0.0 is required
# Redoing requirement with just package name...
# botocore 1.35.36 is installed but botocore<1.30.0,>=1.29.100 is required
# Redoing requirement with just package name...
# numpy 1.26.4 is installed but numpy<3.0,>=2.0 is required
# Redoing requirement with just package name...
# google-api-python-client 2.154.0 is installed but google-api-python-client==1.8.0 is required
# Redoing requirement with just package name...
# packaging 21.3 is installed but packaging>=23.0 is required
# Redoing requirement with just package name...
# The 'cubinlinker' distribution was not found and is required by the application
# Skipping cubinlinker
# cuda-python 12.6.2.post1 is installed but cuda-python<12.0a0,>=11.7.1 is required
# Redoing requirement with just package name...
# The 'cupy-cuda11x>=12.0.0' distribution was not found and is required by the application
# Skipping cupy-cuda11x
# The 'libcudf==24.10.*' distribution was not found and is required by the application
# Skipping libcudf
# pandas 2.2.3 is installed but pandas<2.2.3dev0,>=2.0 is required
# Redoing requirement with just package name...
# The 'ptxcompiler' distribution was not found and is required by the application
# Skipping ptxcompiler
# The 'cupy-cuda11x>=12.0.0' distribution was not found and is required by the application
# Skipping cupy-cuda11x
# The 'cuvs==24.10.*' distribution was not found and is required by the application
# Skipping cuvs
# The 'nvidia-cublas' distribution was not found and is required by the application
# Skipping nvidia-cublas
# The 'nvidia-cufft' distribution was not found and is required by the application
# Skipping nvidia-cufft
# The 'nvidia-curand' distribution was not found and is required by the application
# Skipping nvidia-curand
# The 'nvidia-cusolver' distribution was not found and is required by the application
# Skipping nvidia-cusolver
# The 'nvidia-cusparse' distribution was not found and is required by the application
# Skipping nvidia-cusparse
# The 'cupy-cuda11x>=12.0.0' distribution was not found and is required by the application
# Skipping cupy-cuda11x
# pandas 2.2.3 is installed but pandas<2.2.3dev0,>=2.0 is required
# Redoing requirement with just package name...
# pydantic 2.10.1 is installed but pydantic~=1.10.0 is required
# Redoing requirement with just package name...
# dask 2024.11.2 is installed but dask==2024.9.0 is required
# Redoing requirement with just package name...
# The 'google.auth>=1.14.1' distribution was not found and is required by the application
# Skipping google.auth
# fsspec 2024.6.0 is installed but fsspec==2024.9.0 is required
# Redoing requirement with just package name...
# scipy 1.14.1 is installed but scipy<1.14.0,>=1.7.0 is required
# Redoing requirement with just package name...
# google-api-core 2.11.1 is installed but google-api-core[grpc]<2.0.0dev,>=1.22.2 is required
# Redoing requirement with just package name...
# google-api-core 2.11.1 is installed but google-api-core[grpc]<2.0.0dev,>=1.14.0 is required
# Redoing requirement with just package name...
# pyarrow 17.0.0 is installed but pyarrow<15,>=2 is required
# Redoing requirement with just package name...
# jupyter-lsp 1.5.1 is installed but jupyter-lsp>=2.0.0 is required
# Redoing requirement with just package name...
# jupyter-lsp 1.5.1 is installed but jupyter-lsp>=2.0.0 is required
# Redoing requirement with just package name...
# google-cloud-storage 1.44.0 is installed but google-cloud-storage<3,>=2.2.1 is required
# Redoing requirement with just package name...
# packaging 21.3 is installed but packaging>=22 is required
# Redoing requirement with just package name...
# Shapely 1.8.5.post1 is installed but shapely>=2.0.1 is required
# Redoing requirement with just package name...
# scikit-learn 1.2.2 is installed but scikit-learn>=1.3.1 is required
# Redoing requirement with just package name...
# dill 0.3.8 is installed but dill>=0.3.9 is required
# Redoing requirement with just package name...
# multiprocess 0.70.16 is installed but multiprocess>=0.70.17 is required
# Redoing requirement with just package name...
# matplotlib 3.7.5 is installed but matplotlib>=3.8.0 is required
# Redoing requirement with just package name...
# cuda-python 12.6.2.post1 is installed but cuda-python<12.0a0,>=11.7.1 is required
# Redoing requirement with just package name...
# The 'libcudf==24.10.*' distribution was not found and is required by the application
# Skipping libcudf
# The 'nvidia-cublas' distribution was not found and is required by the application
# Skipping nvidia-cublas
# The 'nvidia-curand' distribution was not found and is required by the application
# Skipping nvidia-curand
# The 'nvidia-cusolver' distribution was not found and is required by the application
# Skipping nvidia-cusolver
# The 'nvidia-cusparse' distribution was not found and is required by the application
# Skipping nvidia-cusparse
# packaging 21.3 is installed but packaging>=23.2 is required
# Redoing requirement with just package name...
# dask 2024.11.2 is installed but dask==2024.9.0 is required
# Redoing requirement with just package name...
# dask-expr 1.1.19 is installed but dask-expr==1.1.14 is required
# Redoing requirement with just package name...
# cuda-python 12.6.2.post1 is installed but cuda-python<12.0a0,>=11.7.1 is required
# Redoing requirement with just package name...
# fsspec 2024.6.0 is installed but fsspec==2024.9.0.* is required
# Redoing requirement with just package name...
# nltk 3.2.4 is installed but nltk>=3.8 is required
# Redoing requirement with just package name...
# numpy 1.26.4 is installed but numpy<2.1.0,>=2.0.0; python_version >= "3.9" is required
# Redoing requirement with just package name...
# The 'libucxx==0.40.*' distribution was not found and is required by the application
# Skipping libucxx
# packaging 21.3 is installed but packaging>=23.2 is required
# Redoing requirement with just package name...
# scipy 1.14.1 is installed but scipy<1.14,>=1.4.1 is required
# Redoing requirement with just package name...
# torchvision 0.19.0 (/opt/conda/lib/python3.10/site-packages)
#     torch 2.4.0 (/opt/conda/lib/python3.10/site-packages)
#         sympy 1.13.3 (/opt/conda/lib/python3.10/site-packages)
#             mpmath 1.3.0 (/opt/conda/lib/python3.10/site-packages)
# torch 2.4.0 (/opt/conda/lib/python3.10/site-packages)
#     sympy 1.13.3 (/opt/conda/lib/python3.10/site-packages)
#         mpmath 1.3.0 (/opt/conda/lib/python3.10/site-packages)
# torchaudio 2.4.0 (/opt/conda/lib/python3.10/site-packages)
#     torch 2.4.0 (/opt/conda/lib/python3.10/site-packages)
#         sympy 1.13.3 (/opt/conda/lib/python3.10/site-packages)
#             mpmath 1.3.0 (/opt/conda/lib/python3.10/site-packages)
# Found existing installation: torch 2.4.0
# Uninstalling torch-2.4.0:
#   Successfully uninstalled torch-2.4.0
# Found existing installation: sympy 1.13.3
# Uninstalling sympy-1.13.3:
#   Successfully uninstalled sympy-1.13.3
# Found existing installation: mpmath 1.3.0
# Uninstalling mpmath-1.3.0:
#   Successfully uninstalled mpmath-1.3.0
# Found existing installation: torchvision 0.19.0
# Uninstalling torchvision-0.19.0:
#   Successfully uninstalled torchvision-0.19.0
# Found existing installation: torchaudio 2.4.0
# Uninstalling torchaudio-2.4.0:
#   Successfully uninstalled torchaudio-2.4.0
# Looking in links: /kaggle/input/eedi-library-lln
# Processing /kaggle/input/eedi-library-lln/torch-2.5.1+cu121-cp310-cp310-linux_x86_64.whl
# Processing /kaggle/input/eedi-library-lln/torchvision-0.20.1+cu121-cp310-cp310-linux_x86_64.whl
# Processing /kaggle/input/eedi-library-lln/torchaudio-2.5.1+cu121-cp310-cp310-linux_x86_64.whl
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.6.0)
# Processing /kaggle/input/eedi-library-lln/nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (from torch)
# Processing /kaggle/input/eedi-library-lln/nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (from torch)
# Processing /kaggle/input/eedi-library-lln/nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (from torch)
# Processing /kaggle/input/eedi-library-lln/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (from torch)
# Processing /kaggle/input/eedi-library-lln/nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (from torch)
# Processing /kaggle/input/eedi-library-lln/nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (from torch)
# Processing /kaggle/input/eedi-library-lln/nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (from torch)
# Processing /kaggle/input/eedi-library-lln/nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (from torch)
# Processing /kaggle/input/eedi-library-lln/nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (from torch)
# Processing /kaggle/input/eedi-library-lln/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (from torch)
# Processing /kaggle/input/eedi-library-lln/nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (from torch)
# Processing /kaggle/input/eedi-library-lln/triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from torch)
# Processing /kaggle/input/eedi-library-lln/sympy-1.13.1-py3-none-any.whl (from torch)
# Processing /kaggle/input/eedi-library-lln/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (from nvidia-cusolver-cu12==11.4.5.107->torch)
# Processing /kaggle/input/eedi-library-lln/mpmath-1.3.0-py3-none-any.whl (from sympy==1.13.1->torch)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Installing collected packages: mpmath, triton, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision, torchaudio
# Successfully installed mpmath-1.3.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 sympy-1.13.1 torch-2.5.1+cu121 torchaudio-2.5.1+cu121 torchvision-0.20.1+cu121 triton-3.1.0
# Looking in links: /kaggle/input/eedi-library-lln
# Processing /kaggle/input/eedi-library-lln/xformers-0.0.28.post3-cp310-cp310-manylinux_2_28_x86_64.whl
# Processing /kaggle/input/eedi-library-lln/unsloth-2024.12.4-py3-none-any.whl
# Processing /kaggle/input/eedi-library-lln/sentence_transformers-3.3.1-py3-none-any.whl
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from xformers) (1.26.4)
# Requirement already satisfied: torch==2.5.1 in /opt/conda/lib/python3.10/site-packages (from xformers) (2.5.1+cu121)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch==2.5.1->xformers) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch==2.5.1->xformers) (4.12.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch==2.5.1->xformers) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch==2.5.1->xformers) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch==2.5.1->xformers) (2024.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch==2.5.1->xformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch==2.5.1->xformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch==2.5.1->xformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.10/site-packages (from torch==2.5.1->xformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch==2.5.1->xformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch==2.5.1->xformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch==2.5.1->xformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch==2.5.1->xformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch==2.5.1->xformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /opt/conda/lib/python3.10/site-packages (from torch==2.5.1->xformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch==2.5.1->xformers) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /opt/conda/lib/python3.10/site-packages (from torch==2.5.1->xformers) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/conda/lib/python3.10/site-packages (from torch==2.5.1->xformers) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.5.1->xformers) (12.4.127)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy==1.13.1->torch==2.5.1->xformers) (1.3.0)
# Processing /kaggle/input/eedi-library-lln/unsloth_zoo-2024.12.1-py3-none-any.whl (from unsloth)
# Processing /kaggle/input/eedi-library-lln/bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl (from unsloth)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from unsloth) (21.3)
# Processing /kaggle/input/eedi-library-lln/tyro-0.9.2-py3-none-any.whl (from unsloth)
# Requirement already satisfied: transformers>=4.46.1 in /opt/conda/lib/python3.10/site-packages (from unsloth) (4.46.3)
# Requirement already satisfied: datasets>=2.16.0 in /opt/conda/lib/python3.10/site-packages (from unsloth) (3.1.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from unsloth) (0.2.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from unsloth) (4.66.4)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from unsloth) (5.9.3)
# Requirement already satisfied: wheel>=0.42.0 in /opt/conda/lib/python3.10/site-packages (from unsloth) (0.43.0)
# Requirement already satisfied: accelerate>=0.34.1 in /opt/conda/lib/python3.10/site-packages (from unsloth) (1.1.1)
# Processing /kaggle/input/eedi-library-lln/trl-0.12.2-py3-none-any.whl (from unsloth)
# Processing /kaggle/input/eedi-library-lln/peft-0.14.0-py3-none-any.whl (from unsloth)
# Requirement already satisfied: protobuf<4.0.0 in /opt/conda/lib/python3.10/site-packages (from unsloth) (3.20.3)
# Requirement already satisfied: huggingface_hub in /opt/conda/lib/python3.10/site-packages (from unsloth) (0.26.2)
# Processing /kaggle/input/eedi-library-lln/hf_transfer-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from unsloth)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (1.14.1)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (10.3.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.34.1->unsloth) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.34.1->unsloth) (0.4.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (2.32.3)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (3.4.1)
# Requirement already satisfied: multiprocess<0.70.17 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (0.70.16)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (3.9.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->unsloth) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.46.1->unsloth) (2024.5.15)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.46.1->unsloth) (0.20.3)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (13.7.1)
# Processing /kaggle/input/eedi-library-lln/cut_cross_entropy-24.12.1-py3-none-any.whl (from unsloth_zoo>=2024.11.8->unsloth)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: docstring-parser>=0.16 in /opt/conda/lib/python3.10/site-packages (from tyro->unsloth) (0.16)
# Processing /kaggle/input/eedi-library-lln/shtab-1.7.1-py3-none-any.whl (from tyro->unsloth)
# Requirement already satisfied: typeguard>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from tyro->unsloth) (4.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (2024.6.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (2.18.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch==2.5.1->xformers) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets>=2.16.0->unsloth) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets>=2.16.0->unsloth) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets>=2.16.0->unsloth) (2024.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth) (1.16.0)
# Installing collected packages: shtab, hf_transfer, tyro, xformers, cut_cross_entropy, bitsandbytes, trl, sentence_transformers, peft, unsloth_zoo, unsloth
# Successfully installed bitsandbytes-0.45.0 cut_cross_entropy-24.12.1 hf_transfer-0.1.8 peft-0.14.0 sentence_transformers-3.3.1 shtab-1.7.1 trl-0.12.2 tyro-0.9.2 unsloth-2024.12.4 unsloth_zoo-2024.12.1 xformers-0.0.28.post3

# %%
import numpy as np
import pandas as pd 
import os
import torch
import gc

from datasets import Dataset
from tqdm import tqdm
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from unsloth import FastLanguageModel
from peft import PeftConfig, PeftModel
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %%
# Load data
DATA_PATH = "/kaggle/input/eedi-mining-misconceptions-in-mathematics"
test = pd.read_csv(DATA_PATH+"/test.csv")
mis_map = pd.read_csv(DATA_PATH+"/misconception_mapping.csv")

# %%
# Format data
test_long = test.melt(id_vars=['QuestionId','ConstructId', 'ConstructName', 'SubjectId', 'SubjectName', 'QuestionText', 'CorrectAnswer'],
                            value_vars=['AnswerAText','AnswerBText', 'AnswerCText', 'AnswerDText'],
                           var_name="Answer",
                           value_name="AnswerText")
test_long['AnswerOption'] = test_long['Answer'].str[6:7]
test_long=test_long.sort_values(['QuestionId', 'AnswerOption'])
test_long['QuestionId_Answer'] = test_long['QuestionId'].astype(str) + '_' + test_long['AnswerOption']
test_long = test_long[test_long['AnswerOption'] != test_long['CorrectAnswer']]

# %% [markdown]
# # Inference of LLM

# %%
max_seq_length = 2048 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

# del model
# gc.collect()
# torch.cuda.empty_cache()

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "/kaggle/input/eedi-load-models/math_solver", # Reminder we support ANY Hugging Face model!
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit
)
# Out:
# ==((====))==  Unsloth 2024.12.4: Fast Qwen2 patching. Transformers:4.46.3.
#    \\   /|    GPU: Tesla T4. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu121. CUDA: 7.5. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# first speaker
prompt_style = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

# Inference time
FastLanguageModel.for_inference(model) # Unsloth has 2x faster inference!

output_list=[]
for idx in tqdm(range(test.shape[0])):
    inputs = tokenizer(
    [
        prompt_style.format(
            """You are a math expert. Solve this question step by step
            """, # instruction
            test['QuestionText'].to_list()[idx], # input
            "", # output - leave this blank for generation!
        )
    ], return_tensors = "pt").to("cuda")
    
    outputs = model.generate(input_ids = inputs.input_ids, attention_mask = inputs.attention_mask, 
                             max_new_tokens = 512, use_cache = True,temperature=0.2)
    outputs_decoded = tokenizer.batch_decode(outputs)
    output_list.append(outputs_decoded[0])
#output_list
# Out:
# 100%|██████████| 3/3 [01:00<00:00, 20.07s/it]

# %%
# Create input for llm
test['steps_to_solve'] = output_list
test['steps_to_solve'] = test['steps_to_solve'].str.split("Response:",expand=True)[1]

test_long = test_long.merge(test[["QuestionText", "steps_to_solve"]], how="left", 
                            on="QuestionText")

test_long['QSA'] = ("Math question: " + test_long['QuestionText'] + "\n" + 
                       "Math construct tested: " + test_long['steps_to_solve'] + "\n" + 
                       "Wrong Answer: " + test_long['AnswerText'])
test_long['Q&A'] = "Math question: " + test_long['QuestionText'] + "\n" + "Wrong Answer: " + test_long['AnswerText']

# %%
# 2nd llm
max_seq_length = 2048 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

del model
gc.collect()
torch.cuda.empty_cache()

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "/kaggle/input/eedi-load-models/llm", # Reminder we support ANY Hugging Face model!
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit
)
# Out:
# ==((====))==  Unsloth 2024.12.4: Fast Qwen2 patching. Transformers:4.46.3.
#    \\   /|    GPU: Tesla T4. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu121. CUDA: 7.5. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# # Loading adapter
# adapter_model_name = "/kaggle/input/eedi-qlora-adapter-synthonly/finetuned_lora"
# model = PeftModel.from_pretrained(model, adapter_model_name)

# %%
# Second speaker
prompt_style = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
def formatting_prompts_func(examples):
    inputs       = examples["Q&A"] # examples["problem"]
    outputs      = examples["MisconceptionName"] # examples["solution"]
    texts = []
    for input, output in zip(inputs, outputs):
        text = prompt_style.format(input, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts}

# Inference time
FastLanguageModel.for_inference(model) # Unsloth has 2x faster inference!

output_list =[]

for idx in tqdm(range(test_long.shape[0])):
    #print(idx)
    inputs = tokenizer(
    [
        prompt_style.format(
            """You are a math teacher. You are given a math question, and the steps required to solve the question.
            A student selected the wrong answer to the question. What misundestanding or misconception does the student have?
            Summarise concisely in 1-2 sentences.""", # instruction
            test_long['QSA'].to_list()[idx], # input
            "", # output - leave this blank for generation!
        )
    ], return_tensors = "pt").to("cuda")
    
    outputs = model.generate(input_ids = inputs.input_ids, attention_mask = inputs.attention_mask, 
                             max_new_tokens = 128, use_cache = True)
    outputs_decoded = tokenizer.batch_decode(outputs)
    output_list.append(outputs_decoded[0])

# Add LLM response to dataset
test_long['llm_response'] = output_list
test_long['llm_response'] = test_long['llm_response'].str.split("Response:\n",expand=True,n=2)[1].str.replace('<|endoftext|>', '')
# Out:
# 100%|██████████| 9/9 [01:18<00:00,  8.77s/it]

# %%
# For misconceptions
model = SentenceTransformer("/kaggle/input/eedi-load-models/embedding_model", 
                            trust_remote_code=True)
misconceptions = mis_map["MisconceptionName"].to_list()
misconception_embeddings = model.encode(misconceptions)
# Out:
# Batches:   0%|          | 0/81 [00:00<?, ?it/s]

# %%
# Supporting functions
def find_most_similar_misconception(generated_misconception, misconception_embeddings, misconceptions):
    # Encode the generated misconception
    gen_misconception_embedding = model.encode([generated_misconception])
    
    # Calculate cosine similarity between the generated misconception and all known misconceptions
    similarities = cosine_similarity(gen_misconception_embedding, misconception_embeddings)[0]
    
    # Get indices of misconceptions sorted by similarity
    sorted_indices = np.argsort(similarities)[::-1]
    
    # Get sorted misconceptions and similarity scores
    sorted_misconceptions = [(misconceptions[i], similarities[i]) for i in sorted_indices]
    
    return sorted_misconceptions

def find_id(list_misconception):
    string_id=""
    i=0
    for misc in list_misconception:
        i+=1
        ind=misconceptions.index(misc[0])
        if i==len(list_misconception):
            string_id=string_id+str(ind)
        else:
            string_id=string_id+str(ind)+" "
    return string_id

# %%
# # Find misconception to LLM response
MisconceptionId=[]
for i in range(len(test_long)):
    simil_misc=find_most_similar_misconception(test_long["llm_response"].tolist()[i], misconception_embeddings, misconceptions)
    MisconceptionId.append(find_id(simil_misc[:25]))

test_long['MisconceptionId'] = MisconceptionId
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#test_long.to_csv('chk_output.csv', index=False)

# %%
test_long[['QuestionId_Answer', 'MisconceptionId']].to_csv("submission.csv", index=False)
